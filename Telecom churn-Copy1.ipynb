# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\HP\telcom_churndataset.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head(50)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
#### DATA CLEANING

# %%
##Convert SeniorCitizen to 'Yes'/'No' for consistency
df['SeniorCitizen'] = df['SeniorCitizen'].replace({1: 'Yes', 0: 'No'})
df
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            No     Yes         No       1
# 1     5575-GNVDE    Male            No      No         No      34
# 2     3668-QPYBK    Male            No      No         No       2
# 3     7795-CFOCW    Male            No      No         No      45
# 4     9237-HQITU  Female            No      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
###Locate rows where TotalCharges is just a space
space_rows = df[df['TotalCharges'] == " "]
print(f"Indices with spaces: {space_rows.index.tolist()}")
# Out:
# Indices with spaces: [488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754]

# %%
###Fix: Replace spaces with '0', then convert the whole column to float
df['TotalCharges'] = df['TotalCharges'].replace(" ", "0").astype(float)

# %%
###Verify: Check if there are any 0 values now in those specific rows
print(df.loc[space_rows.index, ['customerID', 'TotalCharges']])
# Out:
#       customerID  TotalCharges
# 488   4472-LVYGI           0.0
# 753   3115-CZMZD           0.0
# 936   5709-LVOEQ           0.0
# 1082  4367-NUYAO           0.0
# 1340  1371-DWPAZ           0.0
# 3331  7644-OMVMY           0.0
# 3826  3213-VVOLG           0.0
# 4380  2520-SGTTA           0.0
# 5218  2923-ARZLG           0.0
# 6670  4075-WKNIU           0.0
# 6754  2775-SEFEE           0.0

# %% [markdown]
# #### The Commitment Gap
# - ***The Literature:*** Research shows that "Month-to-Month" plans act like an open exit. Without a long-term contract or a cancellation fee, customers are much more likely to "shop around" and leave the moment a competitor offers a better deal.
# - ***The Hypothesis:*** Customers on Month-to-Month contracts will have a significantly higher churn rate than those on one- or two-year plans.
# - ***Source:*** PubMed Central (PMC) via the National Institutes of Health.

# %% [markdown]
# #### The "Digital Glue" Theory
# - ***The Literature:*** Experts found that "Value-Added Services" (like Online Security and Tech Support) make a company "sticky." When a customer relies on you for their safety and troubleshooting, it becomes a major headache for them to switch everything over to a new provider.
# - ***The Hypothesis:*** Having Online Security and Tech Support will be the strongest predictors of a customer staying, regardless of how much they pay monthly
# - ***Source:*** Frontiers in Artificial Intelligence

# %% [markdown]
# #### The Newbie Risk Window
# - ***The Literature:*** Statistics show that the first year of a service is the "danger zone." If a customer survives the initial setup and the first few bills without getting frustrated, they usually fall into a habit and stay loyal for a long time.
# - ***The Hypothesis:*** Churn will be highest for customers with a Tenure of less than 12 months and will drop drastically for anyone who has been around for over two years.
# - ***Source:***  Algorithms Journal (MDPI)

# %% [markdown]
# #### The Tech Frustration Factor
# - ***The Literature:*** High-speed Fiber Optic internet is great, but if it's too complex and there's no support, it actually drives people away.
# - ***The Hypothesis:*** Senior Citizens will show high churn rates if they have Fiber Optic internet but don't have Tech Support included in their package.
# - ***Source:*** Frontiers in Artificial Intelligence

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.histplot(df['tenure'], bins=30, kde=True, color='tomato')
plt.title('Distribution of Tenure (Months)')
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.show()
#highest frequency of customers are clustered at lowest tenure with count declining as tenure increases.
#tenure --> time period

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x='Contract', data=df,hue='Contract', palette='Set2')
plt.title('Univariate: Distribution of Contract Types')
plt.show()

# %% [raw]
# What it shows: The popularity of different contract lengths.
# Pattern: Month-to-month contracts are the most common choice for customers, followed by two-year contracts, while one-year contracts are the least frequent.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.histplot(df['MonthlyCharges'], bins=30, color='salmon')
plt.title('Univariate: Distribution of Monthly Charges')
plt.show()
#large portion of customers pays a minimal monthly charges

# %% [raw]
# What it shows: The range of monthly prices customers pay.
# Pattern: A huge portion of the customer base is on very low-cost plans. As prices increase, the number of customers fluctuates, with another smaller peak for those paying high-tier premium prices.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='InternetService', data=df, hue='InternetService',palette='viridis')
plt.title('Univariate: Types of Internet Service')
plt.show()

# %% [raw]
# What it shows: Which internet technologies customers use.
# Pattern: Fiber optic is the most popular service, followed closely by DSL. A smaller group of customers does not use the company's internet service at all.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='PaymentMethod', data=df, hue='PaymentMethod', palette='magma')
plt.title('Univariate: Distribution of Payment Methods')
plt.xticks(rotation=0)
plt.show()

# %% [raw]
# What it shows: How customers pay their bills.
# Pattern: Electronic checks are the most widely used payment method. The other three methods (mailed checks, bank transfers, and credit cards) are used roughly equally by the rest of the customer base.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Contract', hue='Churn', palette='viridis')
plt.title('Bivariate: Contract Type vs Churn')
plt.show()

# %% [raw]
# What it shows: How contract length affects the decision to leave.
# Pattern: The vast majority of people who leave are on month-to-month plans. In contrast, those on one-year or two-year contracts are highly unlikely to cancel their service.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='InternetService', hue='Churn', palette='rocket')
plt.title('Bivariate: Internet Service vs Churn')
plt.show()

# %% [raw]
# What it shows: Which service tiers have the most departures.
# Pattern: Fiber optic users show a much higher tendency to leave compared to DSL users or those with no internet service. This suggests dissatisfaction specifically within the high-speed fiber segment.

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Churn', y='MonthlyCharges', hue='Churn', palette='muted')
plt.title('Average Monthly Charges by Churn Status')
plt.ylabel('Mean Monthly Charges ($)')
plt.show()
#Higher cost higher risk
#high monthly bills is a strong churn signal. 
#This often happens when customers feel price no longer matches the value or they find cheaper competitor

# %% [raw]
# What it shows: If higher costs drive customers away.
# Pattern: On average, customers who leave were paying noticeably higher monthly fees than those who stayed. Price sensitivity appears to be a key driver for churn.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='PaymentMethod', hue='Churn', palette='mako')
plt.title('Bivariate Analysis: Payment Method vs. Churn')
plt.xticks(rotation=0)
plt.show()

# %% [raw]
# What it shows: If how you pay relates to how long you stay.
# Pattern: Customers paying via electronic checks are disproportionately more likely to leave. Those using automated methods (like credit cards or bank transfers) show much higher loyalty.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Contract', y='MonthlyCharges', hue='Churn', palette='viridis')
plt.title('Multivariate: Average Monthly Charges by Contract & Churn')
plt.ylabel('Average Monthly Charges ($)')
plt.show()

# %% [raw]
# What it shows: The intersection of price, contract type, and churn.
# Pattern: Regardless of the contract type, those who churned were almost always paying higher monthly fees than those who remained. This reinforces that even within a specific contract group, high costs are a primary reason for leaving.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='tenure', y='MonthlyCharges', hue='Churn', marker='o')
plt.title('Multivariate: Monthly Charges Trend over Tenure (Binned) by Churn')
plt.xlabel('Tenure (6-month intervals)')
plt.ylabel('Average Monthly Charges ($)')
plt.show()

# %% [raw]
# What it shows: How charges change over time for those who stay vs. those who leave.
# Pattern: Customers who stay generally have stable or lower monthly charges over time. Customers who eventually leave consistently have higher monthly charges throughout their entire relationship with the company, regardless of how long they stayed.
